# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.3 torch-1.13.1 CUDA:0 (NVIDIA A100 80GB PCIe, 81104MiB)
# Setup complete ✅ (64 CPUs, 250.9 GB RAM, 12.3/50.0 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /scratch/xiwenc/capseg_final

# %%
# !mv test_name1 test_name2

# %%
from roboflow import Roboflow

# %%
# !mv $data_path datasets

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=./datasets/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.0.101 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.97 🚀 Python-3.8.3 torch-1.13.1 CUDA:0 (NVIDIA A100 80GB PCIe, 81104MiB)
# ...

# %%
for i in [3,4,5]: # [2,3,4,5]
    data_path = f'datasets_det{i}'
    # !mv $data_path datasets
    # !yolo task=detect mode=train model=yolov8x.pt data=./datasets/data.yaml epochs=100 imgsz=640 plots=True
    # !mv datasets $data_path 
    rf = Roboflow(api_key="89hrk4aVWlA7jd5qmqTE")
    project = rf.workspace("capdetect").project(f"data_prep_det{i}")
    project.version(1).deploy(model_type="yolov8", model_path=f"runs/detect/train000{i}/")
    


    # rf = Roboflow(api_key="89hrk4aVWlA7jd5qmqTE")
    # project = rf.workspace("capdetect").project(f"data_prep_det{i}")
# Out:
# New https://pypi.org/project/ultralytics/8.0.101 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.97 🚀 Python-3.8.3 torch-1.13.1 CUDA:0 (NVIDIA A100 80GB PCIe, 81104MiB)
# ...

# %%
i
# Out:
# 2

# %%
# rf = Roboflow(api_key="89hrk4aVWlA7jd5qmqTE")
# project = rf.workspace("capdetect").project(f"data_prep_det{i}")
# project.version(1).deploy(model_type="yolov8", model_path=f"runs/detect/train000{i}/")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Dependency ultralytics<=8.0.20 is required but found version=8.0.97, to fix: `pip install ultralytics<=8.0.20`
# View the status of your deployment at: https://app.roboflow.com/capdetect/data_prep_det2/deploy/1
# Share your model with the world at: https://universe.roboflow.com/capdetect/data_prep_det2/model/1

# %%
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.25 source=datasets/test/images save=True
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (8)Ultralytics YOLOv8.0.20 🚀 Python-3.8.3 torch-1.13.1 CUDA:0 (NVIDIA A100-PCIE-40GB, 40389MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/5 /scratch/xiwenc/capseg/datasets/test/images/104_jpg.rf.e310c196391d145e7b55786d619c94de.jpg: 800x800 7 capillarys, 12 cells, 8.1ms
# image 2/5 /scratch/xiwenc/capseg/datasets/test/images/105_jpg.rf.86635ef50dff65cabffc7f0a61a929a9.jpg: 800x800 5 capillarys, 8 cells, 7.9ms
# image 3/5 /scratch/xiwenc/capseg/datasets/test/images/114_jpg.rf.cab428000119beb9a826fcfb718766fe.jpg: 800x800 7 capillarys, 17 cells, 8.2ms
# image 4/5 /scratch/xiwenc/capseg/datasets/test/images/2_jpg.rf.5c030e47b8d1e88d31af8b5ca44e67ee.jpg: 800x800 8 capillarys, 16 cells, 8.0ms
# image 5/5 /scratch/xiwenc/capseg/datasets/test/images/4_jpg.rf.657f3fb5642fbdff8d220d923c1dd573.jpg: 800x800 10 capillarys, 11 cells, 7.9ms
# ...

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="JLIM9vYyTTnriWNOSC96")
# project = rf.workspace("capdec2").project("capdet3")
# # dataset = project.version(2).download("yolov5")

# # rf = Roboflow(api_key="89hrk4aVWlA7jd5qmqTE")


# # project = rf.workspace().project("capdet3")

# project.version(2).deploy(model_type="yolov8", model_path=f"runs/detect/train7/")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/capdec2/capdet3/deploy/2
# Share your model with the world at: https://universe.roboflow.com/capdec2/capdet3/model/2

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="89hrk4aVWlA7jd5qmqTE")
project = rf.workspace("capdetect").project("data_prep")
# dataset = project.version(1).download("yolov5")

project.version(2).deploy(model_type="yolov8", model_path=f"runs/detect/train0003/")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/capdetect/data_prep/deploy/2
# Share your model with the world at: https://universe.roboflow.com/capdetect/data_prep/model/2
